# %%
# !pip install xgboost

# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import MinMaxScaler

from xgboost import XGBClassifier

from sklearn.model_selection import cross_val_score

# %%
resource = "emnist-digits-train.csv"
df_train = pd.read_csv(resource, header=None)
print(df_train.info())
data_train = df_train.to_numpy()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240000 entries, 0 to 239999
# Columns: 785 entries, 0 to 784
# dtypes: int64(785)
# memory usage: 1.4 GB
# None

# %%
X = data_train[:, 1:]
y = data_train[:, 0]

# %%
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
seed = 60
scoring = 'accuracy'
cv=10

def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

# %%
xgb_clf = XGBClassifier(n_estimators=1000, random_state=seed)

xgb_clf_results = cross_val_score(xgb_clf, X_scaled, y, cv=cv, scoring=scoring, n_jobs=-1)

# %%
display(xgb_clf_results)

# %%
np.mean(xgb_clf_results)
